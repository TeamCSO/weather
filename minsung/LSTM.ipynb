# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset
from espnet2.asr.encoder.conformer_encoder import ConformerEncoder

# %%
train_df = pd.read_csv('data/df/train_df.csv')

# %%
train_X = train_df.drop(['Dates','Date','heat_supply'], axis=1)
train_Y = train_df['heat_supply']
# train_X.to_csv("data/df/train_X.csv",index=False)
# train_Y.to_csv("data/df/train_Y.csv",index=False)

# %%
train_X = train_X.iloc[:,5:]

# %%
class CustomDataset(Dataset):
    def __init__(self, data_list):
        self.data_list = data_list
    def __len__(self):
        return len(self.data_list)

    def __getitem__(self, index):
        data = np.load(self.data_list[index])
        return data
train_dataset = CustomDataset(
criterion = CustomLoss(mode, use_galoss)
optimizer = optim.RAdam(model.parameters(), lr=lr)
# Out:
#         wind_direction  in_tmperature  in_humidity  shield_light_h  \
# 4                  123          17.60       64.700             0.0
# 5                  121          17.70       63.500             0.0
# 6                  130          17.80       63.100             0.0
# 7                  153          18.00       63.000             0.0
# 8                  155          18.20       61.900             0.0
# ...                ...            ...          ...             ...
# 130929              57          18.15       70.560             0.0
# 130930              57          18.05       72.215             0.0
# 130931              40          18.20       70.705             0.0
# 130932              36          18.30       70.690             0.0
# 130933              36          18.35       70.355             0.0
#
#         shield_tmperature_h  shield_energy_h  shield_energy_v  exhaust_fan  \
# 4                       0.0              0.0              0.0          0.0
# ...

# %%
class WetherEstimator(ASRInterface, torch.nn.Module):
    def __init__(self):
        super(WetherEstimator, self).__init__()
        self.input_layer = nn.Sequential(
            nn.Linear(22, 32),
            nn.Sigmoid()
        )
        self.encoder = ConformerEncoder(input_size=32, output_size=32)
        self.output_layer = nn.Sequential(
            nn.Linear(32, 1),
            nn.Sigmoid()
        )
        
    def forward(self, X):
        Y = self.input_layer(X)
        Y = self.encoder(Y)
        Y = self.output_layer(Y)
        return Y
